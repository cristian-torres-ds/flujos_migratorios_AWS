# %% [markdown]
# # Unión de data sets

# %%
# importamos librerías
import pandas as pd
import numpy as np
# venv/Scripts/Activate.ps1

# %% [markdown]
# ## Remesas

# %%
# Cargamos data frame remesas
# pip install openpyxl
# https://www.knomad.org/sites/default/files/2023-06/remittance_inflows_brief_38_june_2023_3.xlsx

df_remesas = pd.read_excel('Data/remittance_inflows_brief_38_june_2023_3.xlsx')

# Ordenamos por vol remesas 2022
df_remesas = df_remesas.sort_values(2022, ascending=False)
df_remesas.head(3)
# Out:
#     Remittance inflows (US$ million)           2000           2001  \
# 215                            World  117547.249056  128646.539706
# 214  Low-and Middle-Income Countries   70734.048954   79690.322811
# 87                             India   12883.465957   14273.018778
#
#               2002           2003           2004           2005  \
# 215  152485.500221  186659.719050  215981.484125  284061.448830
# 214   94553.671103  117933.543478  135885.055516  191499.499775
# 87    15735.736286   20999.150983   18750.377107   22125.089480
#
#               2006           2007           2008  ...           2013  \
# 215  327330.931185  394733.443904  458582.545202  ...  580560.918490
# 214  224581.485656  273324.818520  319665.501522  ...  421240.115512
# 87    28333.642280   37216.755275   49977.276916  ...   69970.360847
#
#               2014           2015           2016           2017  \
# 215  608328.147752  596214.035952  590438.537230  640303.562473
# 214  442064.169561  441420.524702  434909.947832  475165.070860
# 87    70388.642797   68909.693353   62744.364090   68967.175500
#
#               2018           2019           2020           2021           2022
# 215  695442.504461  726935.512033  716884.545697  791113.830667  831102.959209
# 214  521549.766177  547554.385848  541662.326103  599341.756181  647193.224941
# 87    78790.170929   83332.078002   83149.172934   89375.152218  111221.774722
#
# [3 rows x 24 columns]

# %%
# Renombramos columna año 2022
df_remesas.rename(columns = {'2022e':2022}, inplace = True)

# Eliminamos regiones, para tomar solo paises
df_remesas = df_remesas[(df_remesas["Remittance inflows (US$ million)"] != "World") &
                        (df_remesas["Remittance inflows (US$ million)"] != "Low-and Middle-Income Countries") &
                        (df_remesas["Remittance inflows (US$ million)"] != "Egypt, Arab Rep.")]

# Nos quedamos con los 5 más significativos
df_remesas = df_remesas.head()
df_remesas
# Out:
#     Remittance inflows (US$ million)          2000          2001  \
# 87                             India  12883.465957  14273.018778
# 125                           Mexico   7524.742980  10146.263000
# 40                             China    758.082000   1209.000000
# 152                      Philippines   6924.000000   8760.000000
# 67                            France   8869.551607   9194.240138
#
#              2002          2003          2004          2005          2006  \
# 87   15735.736286  20999.150983  18750.377107  22125.089480  28333.642280
# 125  11029.448100  16653.686410  19861.747957  22741.840918  26542.800000
# 40    2353.070422   4625.331810   6641.220179  23625.899319  27565.193759
# 152   9735.000000  10239.000000  11468.000000  13732.600000  15496.088457
# 67   10599.319442  12231.755971  13342.614138  14205.076473  15535.237652
#
#              2007          2008  ...          2013          2014  \
# 87   37216.755275  49977.276916  ...  69970.360847  70388.642797
# 125  26879.863159  26041.489177  ...  23188.811955  24802.081325
# 40   38395.039993  47742.805394  ...  59491.287194  62332.342308
# 152  16437.434092  18850.672419  ...  26716.840269  28690.797896
# 67   17586.416269  20085.696123  ...  24412.282153  25358.374728
#
#              2015          2016          2017          2018          2019  \
# 87   68909.693353  62744.364090  68967.175500  78790.170929  83332.078002
# 125  26233.171803  28690.957406  32270.507679  35768.416627  39021.789685
# 40   63937.646592  60999.999488  63875.674112  67413.592064  68398.475114
# 152  29799.395700  31141.973475  32809.770434  33808.967986  35167.471832
# 67   24066.989837  24042.348847  24884.547856  26229.274711  30024.725081
#
#              2020          2021           2022
# 87   83149.172934  89375.152218  111221.774722
# 125  42878.274907  54130.298399   61099.607915
# 40   59506.673349  53000.000000   51000.000000
# 152  34882.844550  36685.313168   38048.724400
# 67   28823.157458  32077.312215   30044.437807
#
# [5 rows x 24 columns]

# %%
# Listamos años del 2012 al 2022
anios = list(range(2012, 2023))
print(anios)

# Listamos los paises
paises = df_remesas["Remittance inflows (US$ million)"].tolist()
paises
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# ['India', 'Mexico', 'China', 'Philippines', 'France']

# %%
# Convertimos la columna paises en índice
df_remesas.set_index("Remittance inflows (US$ million)", inplace=True)
df_remesas
# Out:
#                                           2000          2001          2002  \
# Remittance inflows (US$ million)
# India                             12883.465957  14273.018778  15735.736286
# Mexico                             7524.742980  10146.263000  11029.448100
# China                               758.082000   1209.000000   2353.070422
# Philippines                        6924.000000   8760.000000   9735.000000
# France                             8869.551607   9194.240138  10599.319442
#
#                                           2003          2004          2005  \
# Remittance inflows (US$ million)
# India                             20999.150983  18750.377107  22125.089480
# Mexico                            16653.686410  19861.747957  22741.840918
# China                              4625.331810   6641.220179  23625.899319
# Philippines                       10239.000000  11468.000000  13732.600000
# France                            12231.755971  13342.614138  14205.076473
#
#                                           2006          2007          2008  \
# Remittance inflows (US$ million)
# India                             28333.642280  37216.755275  49977.276916
# Mexico                            26542.800000  26879.863159  26041.489177
# China                             27565.193759  38395.039993  47742.805394
# Philippines                       15496.088457  16437.434092  18850.672419
# France                            15535.237652  17586.416269  20085.696123
#
#                                           2009  ...          2013  \
# Remittance inflows (US$ million)                ...
# India                             49204.000000  ...  69970.360847
# Mexico                            22075.734996  ...  23188.811955
# China                             41600.374919  ...  59491.287194
# Philippines                       19959.507639  ...  26716.840269
# France                            19665.370194  ...  24412.282153
#
#                                           2014          2015          2016  \
# Remittance inflows (US$ million)
# India                             70388.642797  68909.693353  62744.364090
# Mexico                            24802.081325  26233.171803  28690.957406
# China                             62332.342308  63937.646592  60999.999488
# Philippines                       28690.797896  29799.395700  31141.973475
# France                            25358.374728  24066.989837  24042.348847
#
#                                           2017          2018          2019  \
# Remittance inflows (US$ million)
# India                             68967.175500  78790.170929  83332.078002
# Mexico                            32270.507679  35768.416627  39021.789685
# China                             63875.674112  67413.592064  68398.475114
# Philippines                       32809.770434  33808.967986  35167.471832
# France                            24884.547856  26229.274711  30024.725081
#
#                                           2020          2021           2022
# Remittance inflows (US$ million)
# India                             83149.172934  89375.152218  111221.774722
# Mexico                            42878.274907  54130.298399   61099.607915
# China                             59506.673349  53000.000000   51000.000000
# Philippines                       34882.844550  36685.313168   38048.724400
# France                            28823.157458  32077.312215   30044.437807
#
# [5 rows x 23 columns]

# %%
# Creamos un dataset vacío para completar
df_hechos = pd.DataFrame(columns=["anio", "pais", "Remittance inflows (US$ million)", "aux", "TAR (%)"])
df_hechos
# Out:
# Empty DataFrame
# Columns: [anio, pais, Remittance inflows (US$ million), aux, TAR (%)]
# Index: []

# %%
# Completamos el dataset vacío
for pais in paises:
    for anio in anios:
        df_hechos.loc[len(df_hechos.index)] = [anio,
                                               pais,
                                               df_remesas.loc[pais, anio],
                                               str(anio)+pais,
                                               (df_remesas.loc[pais, anio] - df_remesas.loc[pais, anio-1]) / df_remesas.loc[pais, anio] * 100]

# %%
df_hechos.head(12)
# Out:
#     anio    pais  Remittance inflows (US$ million)         aux    TAR (%)
# 0   2012   India                      68820.517838   2012India   9.185404
# 1   2013   India                      69970.360847   2013India   1.643329
# 2   2014   India                      70388.642797   2014India   0.594246
# 3   2015   India                      68909.693353   2015India  -2.146214
# 4   2016   India                      62744.364090   2016India  -9.826108
# 5   2017   India                      68967.175500   2017India   9.022860
# 6   2018   India                      78790.170929   2018India  12.467285
# 7   2019   India                      83332.078002   2019India   5.450371
# 8   2020   India                      83149.172934   2020India  -0.219972
# 9   2021   India                      89375.152218   2021India   6.966119
# 10  2022   India                     111221.774722   2022India  19.642397
# 11  2012  Mexico                      23208.649190  2012Mexico  -1.021220

# %% [markdown]
# ---

# %% [markdown]
# ## PIB

# %%
# Cargamos el dataset
# pip install xlrd
# https://api.worldbank.org/v2/en/indicator/NY.GDP.MKTP.CD?downloadformat=excel
df_pib = pd.read_excel('Data\API_NY.GDP.MKTP.CD_DS2_en_excel_v2_5795872.xls', sheet_name="Data", header=3)
df_pib.head(3)
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.112502e+10  2.161623e+10  2.350628e+10  2.804836e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
#
#            1964          1965  ...          2013          2014          2015  \
# 0           NaN           NaN  ...  2.727933e+09  2.791061e+09  2.963128e+09
# 1  2.592067e+10  2.947210e+10  ...  9.859871e+11  1.006526e+12  9.273485e+11
# 2  8.000000e+08  1.006667e+09  ...  2.056449e+10  2.055058e+10  1.999814e+10
#
#            2016          2017          2018          2019          2020  \
# 0  2.983799e+09  3.092179e+09  3.276188e+09  3.395794e+09  2.610039e+09
# 1  8.851764e+11  1.021043e+12  1.007196e+12  1.000834e+12  9.275933e+11
# 2  1.801955e+10  1.889635e+10  1.841886e+10  1.890450e+10  2.014345e+10
#
#            2021          2022
# 0  3.126019e+09           NaN
# 1  1.081998e+12  1.169484e+12
# 2  1.458314e+10           NaN
#
# [3 rows x 67 columns]

# %%
# Filtramos los paises
df_pib = df_pib[df_pib["Country Name"].isin(paises)]

# Convertimos a los países en índice
df_pib.set_index("Country Name", inplace=True)
df_pib
# Out:
#              Country Code     Indicator Name  Indicator Code          1960  \
# Country Name
# China                 CHN  GDP (current US$)  NY.GDP.MKTP.CD  5.971625e+10
# France                FRA  GDP (current US$)  NY.GDP.MKTP.CD  6.222548e+10
# India                 IND  GDP (current US$)  NY.GDP.MKTP.CD  3.702988e+10
# Mexico                MEX  GDP (current US$)  NY.GDP.MKTP.CD  1.304000e+10
# Philippines           PHL  GDP (current US$)  NY.GDP.MKTP.CD  7.515892e+09
#
#                       1961          1962          1963          1964  \
# Country Name
# China         5.005669e+10  4.720919e+10  5.070662e+10  5.970813e+10
# France        6.746164e+10  7.560753e+10  8.475920e+10  9.400785e+10
# India         3.923244e+10  4.216148e+10  4.842192e+10  5.648029e+10
# Mexico        1.416000e+10  1.520000e+10  1.696000e+10  2.008000e+10
# Philippines   8.171194e+09  4.954594e+09  5.505023e+09  5.953756e+09
#
#                       1965          1966  ...          2013          2014  \
# Country Name                              ...
# China         7.043601e+10  7.672001e+10  ...  9.570471e+12  1.047562e+13
# France        1.015372e+11  1.100459e+11  ...  2.811877e+12  2.855964e+12
# India         5.955485e+10  4.586546e+10  ...  1.856721e+12  2.039126e+12
# Mexico        2.184000e+10  2.432000e+10  ...  1.274444e+12  1.315356e+12
# Philippines   6.517349e+09  7.189018e+09  ...  2.839028e+11  2.974836e+11
#
#                       2015          2016          2017          2018  \
# Country Name
# China         1.106157e+13  1.123331e+13  1.231049e+13  1.389491e+13
# France        2.439189e+12  2.472964e+12  2.595151e+12  2.790957e+12
# India         2.103588e+12  2.294797e+12  2.651474e+12  2.702930e+12
# Mexico        1.171870e+12  1.078493e+12  1.158912e+12  1.222406e+12
# Philippines   3.064459e+11  3.186270e+11  3.284807e+11  3.468419e+11
#
#                       2019          2020          2021          2022
# Country Name
# China         1.427997e+13  1.468774e+13  1.782046e+13  1.796317e+13
# France        2.728870e+12  2.639009e+12  2.957880e+12  2.782905e+12
# India         2.835606e+12  2.671595e+12  3.150307e+12  3.385090e+12
# Mexico        1.269010e+12  1.090515e+12  1.272839e+12  1.414187e+12
# Philippines   3.768234e+11  3.617511e+11  3.940874e+11  4.042843e+11
#
# [5 rows x 66 columns]

# %%
# Generamos un dataset auxilar vacío
df_pib_aux = pd.DataFrame(columns=["GDP (current US$", "aux"])
df_pib_aux
# Out:
# Empty DataFrame
# Columns: [GDP (current US$, aux]
# Index: []

# %%
# Rellenamos el dataset auxiliar
for pais in paises:
    for anio in anios:
        df_pib_aux.loc[len(df_pib_aux.index)] = [df_pib.loc[pais, str(anio)], str(anio)+pais]

df_pib_aux.head()
# Out:
#    GDP (current US$        aux
# 0      1.827638e+12  2012India
# 1      1.856721e+12  2013India
# 2      2.039126e+12  2014India
# 3      2.103588e+12  2015India
# 4      2.294797e+12  2016India

# %%
# Concatenamos los datos de PIB con los de Remesas
df_hechos = pd.merge(df_hechos, df_pib_aux, on="aux")
df_hechos.head()
# Out:
#    anio   pais  Remittance inflows (US$ million)        aux   TAR (%)  \
# 0  2012  India                      68820.517838  2012India  9.185404
# 1  2013  India                      69970.360847  2013India  1.643329
# 2  2014  India                      70388.642797  2014India  0.594246
# 3  2015  India                      68909.693353  2015India -2.146214
# 4  2016  India                      62744.364090  2016India -9.826108
#
#    GDP (current US$
# 0      1.827638e+12
# 1      1.856721e+12
# 2      2.039126e+12
# 3      2.103588e+12
# 4      2.294797e+12

# %% [markdown]
# ---

# %% [markdown]
# ## Inflación

# %%
# https://api.worldbank.org/v2/en/indicator/FP.CPI.TOTL.ZG?downloadformat=excel

df_inflacion = pd.read_excel('Data\API_FP.CPI.TOTL.ZG_DS2_en_excel_v2_5795732.xls', sheet_name="Data", header=3)
df_inflacion.head(3)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                           Indicator Name  Indicator Code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 2  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  ...      2013      2014      2015      2016      2017  \
# 0   NaN   NaN   NaN  ... -2.372065  0.421441  0.474764 -0.931196 -1.028282
# 1   NaN   NaN   NaN  ...  5.750981  5.370290  5.245878  6.571396  6.399343
# 2   NaN   NaN   NaN  ...  7.385772  4.673996 -0.661709  4.383892  4.975952
#
#        2018      2019      2020      2021       2022
# 0  3.626041  4.257462       NaN       NaN        NaN
# 1  4.720811  4.653665  7.321106  6.824727  10.526577
# 2  0.626149  2.302373       NaN       NaN        NaN
#
# [3 rows x 67 columns]

# %%
# Filtramos los paises
df_inflacion = df_inflacion[df_inflacion["Country Name"].isin(paises)]

# Convertimos a los países en índice
df_inflacion.set_index("Country Name", inplace=True)
df_inflacion.head(3)
# Out:
#              Country Code                         Indicator Name  \
# Country Name
# China                 CHN  Inflation, consumer prices (annual %)
# France                FRA  Inflation, consumer prices (annual %)
# India                 IND  Inflation, consumer prices (annual %)
#
#               Indicator Code      1960      1961      1962      1963  \
# Country Name
# China         FP.CPI.TOTL.ZG       NaN       NaN       NaN       NaN
# France        FP.CPI.TOTL.ZG  4.139936  2.400461  5.331280  4.999153
# India         FP.CPI.TOTL.ZG  1.779878  1.695213  3.632215  2.946161
#
#                    1964      1965       1966  ...       2013      2014  \
# Country Name                                  ...
# China               NaN       NaN        NaN  ...   2.621050  1.921642
# France         3.211192  2.703105   2.602001  ...   0.863715  0.507759
# India         13.355261  9.474759  10.801848  ...  10.017878  6.665657
#
#                   2015      2016      2017      2018      2019      2020  \
# Country Name
# China         1.437024  2.000002  1.593136  2.074790  2.899234  2.419422
# France        0.037514  0.183335  1.032283  1.850815  1.108255  0.476499
# India         4.906973  4.948216  3.328173  3.938826  3.729506  6.623437
#
#                   2021      2022
# Country Name
# China         0.981015  1.973576
# France        1.642331  5.222367
# India         5.131407  6.699034
#
# [3 rows x 66 columns]

# %%
# Generamos un dataset auxilar vacío
df_inflacion_aux = pd.DataFrame(columns=["Inflation, consumer prices (annual %)", "aux"])
df_inflacion_aux
# Out:
# Empty DataFrame
# Columns: [Inflation, consumer prices (annual %), aux]
# Index: []

# %%
# Rellenamos el dataset auxiliar
for pais in paises:
    for anio in anios:
        df_inflacion_aux.loc[len(df_inflacion_aux.index)] = [df_inflacion.loc[pais, str(anio)], str(anio)+pais]

df_inflacion_aux.head()
# Out:
#    Inflation, consumer prices (annual %)        aux
# 0                               9.478997  2012India
# 1                              10.017878  2013India
# 2                               6.665657  2014India
# 3                               4.906973  2015India
# 4                               4.948216  2016India

# %%
# Concatenamos los datos de PIB con los de Remesas
df_hechos = pd.merge(df_hechos, df_inflacion_aux, on="aux")
df_hechos.head()
# Out:
#    anio   pais  Remittance inflows (US$ million)        aux   TAR (%)  \
# 0  2012  India                      68820.517838  2012India  9.185404
# 1  2013  India                      69970.360847  2013India  1.643329
# 2  2014  India                      70388.642797  2014India  0.594246
# 3  2015  India                      68909.693353  2015India -2.146214
# 4  2016  India                      62744.364090  2016India -9.826108
#
#    GDP (current US$  Inflation, consumer prices (annual %)
# 0      1.827638e+12                               9.478997
# 1      1.856721e+12                              10.017878
# 2      2.039126e+12                               6.665657
# 3      2.103588e+12                               4.906973
# 4      2.294797e+12                               4.948216

# %% [markdown]
# ---

# %% [markdown]
# ## Migraciones totales

# %%
# https://api.worldbank.org/v2/en/indicator/SM.POP.NETM?downloadformat=excel

df_migraciones = pd.read_excel('Data\API_SM.POP.NETM_DS2_en_excel_v2_5729254.xls', sheet_name="Data", header=3)
df_migraciones.head(3)
# Out:
#                   Country Name Country Code Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Net migration    SM.POP.NETM
# 1  Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                  Afghanistan          AFG  Net migration    SM.POP.NETM
#
#       1960    1961     1962     1963     1964     1965  ...     2013  \
# 0      0.0  -569.0   -609.0   -646.0   -684.0   -726.0  ...    134.0
# 1 -90849.0 -1348.0 -24259.0 -16266.0  37452.0  11041.0  ... -92842.0
# 2   2606.0  6109.0   7016.0   6681.0   7079.0  10695.0  ...  48076.0
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0      88.0     177.0     170.0     218.0     367.0     412.0       0.0
# 1 -199608.0  394925.0 -864708.0 -343075.0 -366105.0 -187410.0  -48955.0
# 2  255611.0 -281739.0  -90238.0  -47090.0  -47205.0   -8082.0  166821.0
#
#        2021  2022
# 0     501.0   NaN
# 1 -179444.0   NaN
# 2 -183672.0   NaN
#
# [3 rows x 67 columns]

# %%
# Filtramos los paises
df_migraciones = df_migraciones[df_migraciones["Country Name"].isin(paises)]

# Convertimos a los países en índice
df_migraciones.set_index("Country Name", inplace=True)
df_migraciones.head(3)
# Out:
#              Country Code Indicator Name Indicator Code      1960      1961  \
# Country Name
# China                 CHN  Net migration    SM.POP.NETM -118519.0 -179064.0
# France                FRA  Net migration    SM.POP.NETM  160864.0  177923.0
# India                 IND  Net migration    SM.POP.NETM   52264.0  114181.0
#
#                   1962      1963      1964      1965      1966  ...      2013  \
# Country Name                                                    ...
# China        -219144.0 -219686.0 -183384.0 -128537.0  -73698.0  ... -137444.0
# France        189952.0  198822.0  203089.0  202497.0  197365.0  ...   36552.0
# India         110398.0   48986.0    5837.0   19077.0 -144807.0  ... -236387.0
#
#                   2014      2015      2016      2017      2018      2019  \
# Country Name
# China        -198432.0 -155379.0 -153054.0 -180592.0 -296674.0 -302609.0
# France         26585.0   18807.0   14729.0   13175.0   14391.0   17403.0
# India        -310694.0 -475094.0   68119.0 -219656.0 -561563.0 -593495.0
#
#                  2020      2021  2022
# Country Name
# China        -33649.0 -200194.0   NaN
# France        18335.0   20614.0   NaN
# India        -34772.0 -301970.0   NaN
#
# [3 rows x 66 columns]

# %%
# Generamos un dataset auxilar vacío
df_migraciones_aux = pd.DataFrame(columns=["Net migration", "aux"])
df_migraciones_aux
# Out:
# Empty DataFrame
# Columns: [Net migration, aux]
# Index: []

# %%
# Rellenamos el dataset auxiliar
for pais in paises:
    for anio in anios:
        df_migraciones_aux.loc[len(df_migraciones_aux.index)] = [df_migraciones.loc[pais, str(anio)], str(anio)+pais]

df_inflacion_aux.head()
# Out:
#    Inflation, consumer prices (annual %)        aux
# 0                               9.478997  2012India
# 1                              10.017878  2013India
# 2                               6.665657  2014India
# 3                               4.906973  2015India
# 4                               4.948216  2016India

# %%
# Concatenamos los datos de PIB con los de Remesas
df_hechos = pd.merge(df_hechos, df_migraciones_aux, on="aux")
df_hechos.head()
# Out:
#    anio   pais  Remittance inflows (US$ million)        aux   TAR (%)  \
# 0  2012  India                      68820.517838  2012India  9.185404
# 1  2013  India                      69970.360847  2013India  1.643329
# 2  2014  India                      70388.642797  2014India  0.594246
# 3  2015  India                      68909.693353  2015India -2.146214
# 4  2016  India                      62744.364090  2016India -9.826108
#
#    GDP (current US$  Inflation, consumer prices (annual %)  Net migration
# 0      1.827638e+12                               9.478997      -180991.0
# 1      1.856721e+12                              10.017878      -236387.0
# 2      2.039126e+12                               6.665657      -310694.0
# 3      2.103588e+12                               4.906973      -475094.0
# 4      2.294797e+12                               4.948216        68119.0

# %%
df_hechos.to_csv("tabla_de_hechos.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Migraciones a paises

# %%
# Cargamos el dataset
df_mig = pd.read_csv('Data\MIG_31082023183055443.csv')
df_mig.head(3)
# Out:
# C:\Users\cristian_torres\AppData\Local\Temp\ipykernel_10892\4013416875.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mig = pd.read_csv('Data\MIG_31082023183055443.csv')
#    CO2 Country of birth/nationality  VAR  \
# 0  AFG                  Afghanistan  B11
# 1  AFG                  Afghanistan  B11
# 2  AFG                  Afghanistan  B11
#
#                                        Variable  GEN Gender  COU    Country  \
# 0  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 1  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 2  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
#
#     YEA  Year  Value Flag Codes Flags
# 0  2000  2000  887.0        NaN   NaN
# 1  2001  2001  456.0        NaN   NaN
# 2  2002  2002  660.0        NaN   NaN

# %%
# Nos quedamos solo con los datos de los que migran
df_mig = df_mig[df_mig["Variable"] == "Inflows of foreign population by nationality"]

# Se eliminan columnas innecesarias
df_mig = df_mig.drop(columns= ['VAR','GEN','Gender','YEA','Flag Codes','Flags'])

# %%
# se rota la tabla
df_mig = df_mig.pivot_table(index=['Country of birth/nationality','Country'], columns='Year', values='Value')

# %%
# Filtramos paises
df_mig = df_mig.loc[paises]

# %%
df_mig.dropna(inplace = True)

# %%
total_migrantes = df_mig.sum(axis=1)

# %%
# Obtiene el top 5 de países de destino para cada país de origen
top_5 = total_migrantes.groupby('Country of birth/nationality').apply(lambda x: x.nlargest(5).index)

# %%
mask = pd.Series(False, index=df_mig.index)
for pais_origen, paises_destino in top_5.items():
    mask |= ((df_mig.index.get_level_values('Country of birth/nationality') == pais_origen) & 
             df_mig.index.get_level_values('Country').isin(paises_destino.get_level_values(1)))
df_mig = df_mig[mask]

# %%
df_mig = df_mig[anios[:-2]]
df_mig = df_mig.reset_index().melt(id_vars=['Country of birth/nationality', 'Country'])
df_mig
# Out:
#     Country of birth/nationality        Country  Year    value
# 0                          India      Australia  2012  27830.0
# 1                          India         Canada  2012  30915.0
# 2                          India        Germany  2012  18063.0
# 3                          India    New Zealand  2012   8564.0
# 4                          India  United States  2012  64694.0
# ..                           ...            ...   ...      ...
# 220                       France        Belgium  2020  11286.0
# 221                       France         Canada  2020   4605.0
# 222                       France        Germany  2020  11552.0
# 223                       France          Spain  2020  10207.0
# 224                       France    Switzerland  2020  15738.0
#
# [225 rows x 4 columns]

# %%
df_mig["aux"] = df_mig["Year"].astype(str) + df_mig["Country of birth/nationality"]
df_mig
# Out:
#     Country of birth/nationality        Country  Year    value         aux
# 0                          India      Australia  2012  27830.0   2012India
# 1                          India         Canada  2012  30915.0   2012India
# 2                          India        Germany  2012  18063.0   2012India
# 3                          India    New Zealand  2012   8564.0   2012India
# 4                          India  United States  2012  64694.0   2012India
# ..                           ...            ...   ...      ...         ...
# 220                       France        Belgium  2020  11286.0  2020France
# 221                       France         Canada  2020   4605.0  2020France
# 222                       France        Germany  2020  11552.0  2020France
# 223                       France          Spain  2020  10207.0  2020France
# 224                       France    Switzerland  2020  15738.0  2020France
#
# [225 rows x 5 columns]

# %%
df_mig.to_csv("migracion_relacional.csv", index=False)
